# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')

from selenium.webdriver.common.by import By
import time

# %%
product=input('enter the item name  ')
# Out:
# enter the item name  guitar

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.amazon.in/')

# %%
variable = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
variable.send_keys('guitar')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
start=0
end=1
for page in range(start,end):
    
    total_guitar=[]
    guitar=driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for i in guitar:
        total_guitar.append(i.text)
    next_button = driver.find_elements(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')[0]
    next_button.click()

# %%
total_guitar
# Out:
# ['Kadence Frontier guitar with Online Guitar learning course , Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Vault Traveller 34 Inch Acoustic Guitar With Truss Rod, Gig-Bag, Strap, Strings, Polishing Cloth, String Winder, Picks & E-Book - Natural Gloss',
#  'ESH Creations E40CHEQ High Gloss Semi Acoustic Guitar with Foam Padded Bag, Tuner, Pro Capo, Strings Set, Belt, 3 Picks (Natural)',
#  'ESH Creations E41CHEQ Jumbo High Gloss Semi Acoustic Guitar with Foam Padded Bag, Tuner, Pro Capo, Strings Set, Belt, 3 Picks (Natural)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Right hand Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black, small',
#  'Yamaha F280 Acoustic Rosewood Guitar (Natural, Beige)',
#  'Juarez Lindenwood Acoustic Guitar Kit, 38 Inches Cutaway, 38C With Bag, Strings, Pick And Strap, TBS Transparent (Blue Sunburst)',
# ...

# %%
len(total_guitar)
# Out:
# 60

# %%
price3=[]
start=0
end=2
for page in range(start,end):
    prices=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in prices:
        price3.append(i.text)
    next_button = driver.find_elements(By.XPATH, '//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')[0]
next_button.click()

# %%
len(price3)
price60=price3[:-50]
price60
# Out:
# ['4,671',
#  '8,999',
#  '6,497',
#  '5,397',
#  '10,600',
#  '2,199',
#  '13,890',
#  '78,375',
#  '12,699',
#  '6,866',
#  '7,539',
#  '6,999',
#  '9,499',
#  '6,925',
#  '14,728',
#  '3,432',
#  '3,599',
#  '8,030',
#  '9,298',
#  '12,251',
#  '5,897',
#  '999',
#  '2,303',
#  '9,499',
#  '36,927',
#  '7,124',
#  '399',
#  '6,869',
#  '4,999',
#  '1,290',
#  '38,586',
#  '5,491',
#  '6,498',
#  '5,979',
#  '5,869',
#  '12,490',
#  '2,948',
#  '16,350',
#  '4,360',
#  '2,149',
#  '23,274',
#  '4,079',
#  '12,831',
#  '6,899',
#  '14,490',
#  '2,255',
#  '4,559',
#  '9,269',
#  '2,699',
#  '10,250',
#  '7,727',
#  '5,199',
#  '3,050',
#  '2,699',
#  '6,999',
#  '4,671',
#  '8,999',
#  '6,497',
#  '5,397',
#  '10,600']

# %%
start=0
end=2
expected_delivery=[]
for page in range(start,end):
    delivery=driver.find_elements(By.XPATH,'//span[@class="a-color-base a-text-bold"]')
    for i in delivery:
        expected_delivery.append(i.text)
    next_button = driver.find_elements(By.XPATH, '//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')[0]
next_button.click()

# %%
len(expected_delivery)
expected100=expected_delivery[:-36]
expected100
# Out:
# ['Tomorrow, 18 April',
#  'Thursday, 20 April',
#  'Thursday, 20 April',
#  'Tomorrow, 18 April',
#  'Thursday, 20 April',
#  'Tuesday, 25 April',
#  'Tomorrow, 18 April',
#  'Wednesday, 19 April',
#  'Sunday, 23 April',
#  'Wednesday, 19 April',
#  'Sunday, 23 April',
#  'Wednesday, 19 April',
#  'Sunday, 23 April',
#  'Tomorrow, 18 April',
#  'Tomorrow, 18 April',
#  'Thursday, 20 April',
#  'Thursday, 20 April',
#  'Sunday, 23 April',
#  'Thursday, 20 April',
#  'Thursday, 20 April',
#  'Tomorrow, 18 April',
#  'Tomorrow, 18 April',
#  'Wednesday, 19 April',
#  'Wednesday, 19 April',
#  'Tomorrow, 18 April',
#  'Wednesday, 19 April',
#  'Sunday, 23 April',
#  'Sunday, 23 April',
#  'Wednesday, 19 April',
#  'Sunday, 23 April',
#  'Tomorrow, 18 April',
#  'Thursday, 20 April',
#  'Tomorrow, 18 April',
#  'Thursday, 20 April',
#  'Thursday, 20 April',
#  'Sunday, 23 April',
#  'Tomorrow, 18 April',
#  'Wednesday, 19 April',
#  'Sunday, 23 April',
#  'Tuesday, 25 April',
# ...

# %%
avability=[]
avability0=('-')
for i in avability0:
    avability.append('-')

# %%
avability*60
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
exchange=[]
exchange0=('-')
for i in exchange0:
    exchange.append('-')

# %%
exchange*60
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
start=0
end=3
product_url=[]
for page in range (start,end):
    url = driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for i in url:
        product_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')[0]
    next_button.click()
    time.sleep(3)

# %%
product_url
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
len(product_url)
url100=product_url[:-84]
url100
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
len(total_guitar),len(price60),len(expected100),len(exchange*60),len(avability*60),len(url100)
# Out:
# (60, 60, 60, 60, 60, 60)

# %%
df=pd.DataFrame({'guitar':total_guitar,'price':price60,'expected_delivery':expected100,'return':exchange*60,'avalibility':avability*60,'urls':url100})
df
# Out:
#                                                guitar   price  \
# 0   Kadence Frontier guitar with Online Guitar lea...   4,671
# 1   Vault Traveller 34 Inch Acoustic Guitar With T...   8,999
# 2   ESH Creations E40CHEQ High Gloss Semi Acoustic...   6,497
# 3   ESH Creations E41CHEQ Jumbo High Gloss Semi Ac...   5,397
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  10,600
# 5   Intern INT-38C Right hand Acoustic Guitar Kit,...   2,199
# 6   Yamaha F280 Acoustic Rosewood Guitar (Natural,...  13,890
# 7   Juarez Lindenwood Acoustic Guitar Kit, 38 Inch...  78,375
# 8   Juarez Lindenwood Acoustic Guitar Kit, 38 Inch...  12,699
# 9           Intern INT-38C Acoustic Guitar Kit (Blue)   6,866
# 10  Intern INT-38C Lindenwood Acoustic Guitar Kit ...   7,539
# 11  Revel 38 Inches Cutaway Design Acoustic Guitar...   6,999
# 12  Kadence Frontier Series, Acoustic Guitar With/...   9,499
# 13  Juarez Lindenwood Acoustic Guitar, 38 Inches C...   6,925
# ...

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get( 'https://images.google.com/')

# %%
variable=driver.find_element(By.CLASS_NAME,"gLFyf")
variable.send_keys('cake')

# %%
search=driver.find_element(By.CLASS_NAME,"zgAlFc")
search.click()

# %%
for i in range(20):
    
    driver.execute_script('window.scrollBy(0,1000)')

images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_url=[]
img_data=[]

for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if (source=='http'):
            img_url.append(source)
for i in range(len(img_url)):
    if i>10:
        breakBy.XPATH,
    print('download images'.format(i,10))
    response=requests.get(img_url[i])
    file = open("C:/Users/love todawat/Downloads/" + str(i) + ".jpg", "wb")

    file.write(response.content)
    
    
images
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1249040688f2041bb63e27f1d5ce2be0", element="383a19bf-c716-46f7-a27a-d33604fc2507")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1249040688f2041bb63e27f1d5ce2be0", element="4e0f679d-6933-49c2-8743-2ca46d2bff42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1249040688f2041bb63e27f1d5ce2be0", element="a1706f12-885b-4f2d-9487-9a404a59c5ce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1249040688f2041bb63e27f1d5ce2be0", element="44d7bc7a-c367-49aa-8603-6ba402ee7993")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1249040688f2041bb63e27f1d5ce2be0", element="731570b3-a256-447e-977d-45be779045c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1249040688f2041bb63e27f1d5ce2be0", element="8074d6b3-8e42-4b01-af5d-c8e8182d2d25")>,
# ...

# %%
driver=webdriver.Chrome("chromediver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
variable=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
variable.send_keys('Oneplus Nord')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search.click()

# %%
brand_names=[]

brand_name=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')

for i in brand_name:
    brand_names.append(i.text)
brand_names
# Out:
# ['OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)',
#  'OnePlus Nord 2T 5G (Jade Fog, 128 GB)',
#  'OnePlus Nord 2T 5G (Jade Fog, 128 GB)',
#  'OnePlus Nord 2T 5G (Jade Fog, 256 GB)',
#  'OnePlus Nord 2T 5G (Gray Shadow, 128 GB)',
#  'OnePlus Nord 2 5G (Gray Sierra, 128 GB)',
#  'OnePlus Nord CE 5G (Charcoal Ink, 128 GB)',
#  'OnePlus Nord 2 5G (Blue Haze, 128 GB)',
#  'OnePlus Nord CE 5G (Silver Ray, 256 GB)',
#  'OnePlus Nord 2T 5G (Gray Shadow, 128 GB)',
#  'OnePlus Nord 2T 5G (Gray Shadow, 256 GB)',
#  'OnePlus Nord 2T 5G (Gray Shadow, 128 GB)',
#  'OnePlus Nord CE 5G (Charcoal Ink, 256 GB)',
#  'OnePlus Nord CE 5G (Blue Void, 256 GB)',
#  'OnePlus Nord CE 5G (Silver Ray, 128 GB)',
#  'OnePlus Nord CE 5G (Silver Gray, 128 GB)',
#  'OnePlus Nord CE 5G (Charcoal Ink, 128 GB)',
#  'OnePlus Nord CE 5G (Blue Void, 128 GB)',
# ...

# %%
ram_rom=[]
ram_rom0=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"]')[:24]

for i in ram_rom0:
    ram_rom.append(i.text)
ram_rom
# Out:
# ['8 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 months',
#  '6 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 Months',
#  '6 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 months',
#  '8 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 months',
#  '8 GB RAM | 128 GB ROM',
#  '17.02 cm (6.7 inch) Display',
#  '50MP Rear Camera',
#  '4500 mAh Battery']

# %%
display=[]

mobile_display=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"]')[:24]

for i in mobile_display:
    display.append(i.text)
display
# Out:
# ['8 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 months',
#  '6 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 Months',
#  '6 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 months',
#  '8 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 months',
#  '8 GB RAM | 128 GB ROM',
#  '17.02 cm (6.7 inch) Display',
#  '50MP Rear Camera',
#  '4500 mAh Battery']

# %%
url=[]
product_url=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')[:24]

for i in product_url:
    url.append(i.get_attribute('href'))
url
# Out:
# ['https://www.flipkart.com/oneplus-nord-ce-2-lite-5g-blue-tide-128-gb/p/itm7acae55b999e6?pid=MOBGHBNGY5NDH3GV&lid=LSTMOBGHBNGY5NDH3GVAIZDNM&marketplace=FLIPKART&q=Oneplus+Nord&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=ce6bb498-e91c-4248-8942-8ba52a1c43c0.MOBGHBNGY5NDH3GV.SEARCH&ppt=hp&ppn=homepage&ssid=the6dmmxpc0000001681888464568&qH=53863d4d978d5074',
#  'https://www.flipkart.com/oneplus-nord-ce-2-lite-5g-blue-tide-128-gb/p/itm7acae55b999e6?pid=MOBGMFREBAHZQGY9&lid=LSTMOBGMFREBAHZQGY9HACYLB&marketplace=FLIPKART&q=Oneplus+Nord&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=Search&iid=ce6bb498-e91c-4248-8942-8ba52a1c43c0.MOBGMFREBAHZQGY9.SEARCH&ppt=sp&ppn=sp&ssid=the6dmmxpc0000001681888464568&qH=53863d4d978d5074',
# ...

# %%
len(brand_names),len(ram_rom),len(url)
# Out:
# (24, 24, 24)

# %%
df=pd.DataFrame({'mobile_phones':brand_names,'ram|rom|display':ram_rom,'urls':url})
df
# Out:
#                                         mobile_phones  \
# 0       OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)
# 1       OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)
# 2      OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 3      OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 4               OnePlus Nord 2T 5G (Jade Fog, 128 GB)
# 5               OnePlus Nord 2T 5G (Jade Fog, 128 GB)
# 6               OnePlus Nord 2T 5G (Jade Fog, 256 GB)
# 7            OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 8             OnePlus Nord 2 5G (Gray Sierra, 128 GB)
# 9           OnePlus Nord CE 5G (Charcoal Ink, 128 GB)
# 10              OnePlus Nord 2 5G (Blue Haze, 128 GB)
# 11            OnePlus Nord CE 5G (Silver Ray, 256 GB)
# 12           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 13           OnePlus Nord 2T 5G (Gray Shadow, 256 GB)
# 14           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 15          OnePlus Nord CE 5G (Charcoal Ink, 256 GB)
# ...

# %%
driver=webdriver.Chrome('chrome.exe')

# %%
driver.get('https://www.google.co.in/maps/@21.125498,81.914063,5z')

# %%
variable = driver.find_element(By.CLASS_NAME, "tactile-searchbox-input")
variable.send_keys('udaipur')

# %%
search=driver.find_element(By.CLASS_NAME,"mL3xi")
search.click()

# %%
import re
url=driver.current_url
print(url)
variable=re.findall(r'@(.*)z',url)
variable
# Out:
# https://www.google.co.in/maps/@24.610123,73.6338639,12.22z
# ['24.610123,73.6338639,12.22']

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://www.digit.in/')

# %%
gaming_laptop=[]

laptop=driver.find_elements(By.XPATH,'//div[@class="Product-specs"]')
for i in laptop:
    gaming_laptop.append(i.text)
gaming_laptop
# Out:
# ['View Gallery\n+ Compare\nWindows 11 Home\n17.3" (3840 x 2160)\n12th Gen Intel Core i9-12900HX | NA\n2 TB SSD/64 GB DDR5\nFULL SPECS\nOther MSI Laptops',
#  'View Gallery\n+ Compare\nWindows 11 Home\n16" (2560 x 1600)\n12th Gen Intel Core i9-12900HX | 2.3 GHz\n1 TB SSD/32 GB DDR4\n₹ 359,990\nBUY NOW\nFULL SPECS\nOther Lenovo Laptops',
#  'View Gallery\n+ Compare\nWindows 11 Home\n17.3" (1920 x 1080)\n12th Gen Intel Core i9-12900H | 5 GHz\n1 TB SSD/32 GB DDR5\n₹ 389,990\nBUY NOW\nFULL SPECS\nOther Dell Laptops',
#  'View Gallery\n+ Compare\nWindows 11\n16" (2560 x 1600)\n12th Gen Intel Core i7-12700H | 3.5 GHz\n2 TB SSD/32 GB DDR5\n₹ 229,990\nBUY NOW\nFULL SPECS\nOther Acer Laptops',
#  'View Gallery\n+ Compare\nWindows 11 Home\n16.1" (2560 x 1440)\n12th Gen Intel Core i7-12700H | 4.7 GHz\n1 TB SSD/8 GB DDR5\n₹ 177,590\nBUY NOW\nFULL SPECS\nOther HP Laptops',
# ...

# %%
df=pd.DataFrame({'gaming laptops in india':gaming_laptop})
df
# Out:
#                              gaming laptops in india
# 0  View Gallery\n+ Compare\nWindows 11 Home\n17.3...
# 1  View Gallery\n+ Compare\nWindows 11 Home\n16" ...
# 2  View Gallery\n+ Compare\nWindows 11 Home\n17.3...
# 3  View Gallery\n+ Compare\nWindows 11\n16" (2560...
# 4  View Gallery\n+ Compare\nWindows 11 Home\n16.1...
# 5  View Gallery\n+ Compare\nWindows 11 Home\n15.6...
# 6  View Gallery\n+ Compare\nWindows 11 Home\n15.6...
# 7  View Gallery\n+ Compare\nWindows 11 Home\n16.1...
# 8  View Gallery\n+ Compare\nWindows 11 Home\n16" ...
# 9  View Gallery\n+ Compare\nWindows 11 Home\n15.6...

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://www.forbes.com/?sh=21cc9cab2254')

# %%
billionaires=[]

billionaire=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]')[:20]

for i in billionaire:
    billionaires.append(i.text)
billionaires
# Out:
# ['2\nElon Musk\n$180 B\n51\nUnited States\nTesla, SpaceX\nAutomotive',
#  '3\nJeff Bezos\n$114 B\n59\nUnited States\nAmazon\nTechnology',
#  '4\nLarry Ellison\n$107 B\n78\nUnited States\nOracle\nTechnology',
#  '5\nWarren Buffett\n$106 B\n92\nUnited States\nBerkshire Hathaway\nFinance & Investments',
#  '6\nBill Gates\n$104 B\n67\nUnited States\nMicrosoft\nTechnology',
#  '7\nMichael Bloomberg\n$94.5 B\n81\nUnited States\nBloomberg LP\nMedia & Entertainment',
#  '8\nCarlos Slim Helu & family\n$93 B\n83\nMexico\nTelecom\nTelecom',
#  '9\nMukesh Ambani\n$83.4 B\n65\nIndia\nDiversified\nDiversified',
#  '10\nSteve Ballmer\n$80.7 B\n67\nUnited States\nMicrosoft\nTechnology',
#  "11\nFrancoise Bettencourt Meyers & family\n$80.5 B\n69\nFrance\nL'Oréal\nFashion & Retail",
#  '12\nLarry Page\n$79.2 B\n50\nUnited States\nGoogle\nTechnology',
#  '13\nAmancio Ortega\n$77.3 B\n87\nSpain\nZara\nFashion & Retail',
#  '14\nSergey Brin\n$76 B\n49\nUnited States\nGoogle\nTechnology',
# ...

# %%
df=pd.DataFrame({'billionaire':billionaires})
df
# Out:
#                                           billionaire
# 0   2\nElon Musk\n$180 B\n51\nUnited States\nTesla...
# 1   3\nJeff Bezos\n$114 B\n59\nUnited States\nAmaz...
# 2   4\nLarry Ellison\n$107 B\n78\nUnited States\nO...
# 3   5\nWarren Buffett\n$106 B\n92\nUnited States\n...
# 4   6\nBill Gates\n$104 B\n67\nUnited States\nMicr...
# 5   7\nMichael Bloomberg\n$94.5 B\n81\nUnited Stat...
# 6   8\nCarlos Slim Helu & family\n$93 B\n83\nMexic...
# 7   9\nMukesh Ambani\n$83.4 B\n65\nIndia\nDiversif...
# 8   10\nSteve Ballmer\n$80.7 B\n67\nUnited States\...
# 9   11\nFrancoise Bettencourt Meyers & family\n$80...
# 10  12\nLarry Page\n$79.2 B\n50\nUnited States\nGo...
# 11  13\nAmancio Ortega\n$77.3 B\n87\nSpain\nZara\n...
# 12  14\nSergey Brin\n$76 B\n49\nUnited States\nGoo...
# 13  15\nZhong Shanshan\n$68 B\n68\nChina\nBeverage...
# 14  16\nMark Zuckerberg\n$64.4 B\n38\nUnited State...
# 15  17\nCharles Koch\n$59 B\n87\nUnited States\nKo...
# ...

# %%
driver=webdriver.Chrome('chromediver.exe')

# %%
driver.get('https://www.youtube.com/')

# %%
comments=[]

comment=driver.find_elements(By.XPATH,'//div[@class="style-scope ytd-comment-renderer"]')[:30]

for i in comment:
    comments.append(i.text)
comments
# Out:
# ['',
#  '',
#  "gaurav sain\n1 year ago\nThis is my favorite channel. I especially like it when you explain everything so nicely. I wish you a lot of success with the channel and happy life. This is a great channel! I only caught sight of you folks in recent times, but it’s now among my favorite channels. Congratulations on such an amazing achievement, can't wait to see your channel grow even bigger.\n119\nReply",
#  '',
#  "gaurav sain\n1 year ago\nThis is my favorite channel. I especially like it when you explain everything so nicely. I wish you a lot of success with the channel and happy life. This is a great channel! I only caught sight of you folks in recent times, but it’s now among my favorite channels. Congratulations on such an amazing achievement, can't wait to see your channel grow even bigger.\n119\nReply",
#  'gaurav sain\n1 year ago',
#  '',
#  'gaurav sain\n1 year ago',
# ...

# %%
votes=[]

vote=driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-action-buttons-renderer"]')[:30]

for i in vote:
    votes.append(i.text)
votes
# Out:
# ['',
#  '119',
#  '',
#  '178',
#  '',
#  '29',
#  '',
#  '33',
#  '',
#  '63',
#  '',
#  '26',
#  '',
#  '11',
#  '',
#  '651',
#  '',
#  '40',
#  '',
#  '17',
#  '',
#  '16',
#  '',
#  '105',
#  '',
#  '1.1K',
#  '',
#  '329',
#  '',
#  '9']

# %%
times=[]

time=driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')[:30]

for i in time:
    times.append(i.text)
times
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
len(comments),len(votes),len(times)
# Out:
# (30, 30, 30)

# %%
df=pd.DataFrame({'comment':comments,'vote':votes,'time':times})
df
# Out:
#                                               comment  vote time
# 0
# 1                                                       119
# 2   gaurav sain\n1 year ago\nThis is my favorite c...
# 3                                                       178
# 4   gaurav sain\n1 year ago\nThis is my favorite c...
# 5                             gaurav sain\n1 year ago    29
# 6
# 7                             gaurav sain\n1 year ago    33
# 8   This is my favorite channel. I especially like...
# 9                                                        63
# 10
# 11                                                       26
# 12
# 13  amrutha331\n1 year ago\nI love the videos, Har...    11
# 14
# 15  amrutha331\n1 year ago\nI love the videos, Har...   651
# 16                             amrutha331\n1 year ago
# 17                                                       40
# 18                             amrutha331\n1 year ago
# 19  I love the videos, Harry. Just a small correct...    17
# 20
# ...

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get(' https://www.hostelworld.com/')

# %%
variable=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/div/div/input')
variable.send_keys('london')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[5]/button')
search.click()

# %%
hostel_name=[]
distance=[]
rating=[]
review=[]
price=[]
private_from_price=[]

# %%
hostel_name=[]
hostel=driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')

for i in hostel:
    hostel_name.append(i.text)
hostel_name
# Out:
# ['Hostel One Notting Hill',
#  "St Christopher's Village",
#  'Generator London',
#  'Urbany Hostel London',
#  'Smart Hyde Park Inn Hostel',
#  "St Christopher's Camden",
#  'Queen Elizabeth Chelsea',
#  "St Christopher's Greenwich",
#  "St Christopher's Shepherds Bush",
#  'Bell House Hostel',
#  'PubLove @ The White Ferry, Victoria',
#  'Hostelle London',
#  'Kensal Green Backpackers',
#  'PubLove @ The Crown, Battersea',
#  'London Waterloo Hostel',
#  'Elmwood Hotel',
#  'PubLove @ The Exmouth Arms, Euston',
#  'PubLove @ The Green Man, Paddington',
#  'Hanover Hotel',
#  'Budget London Apartments',
#  'The London Home Hostel']

# %%
distance=[]
distances=driver.find_elements(By.XPATH,'//span[@class="description"]')

for i in distances:
    distance.append(i.text)
distance
# Out:
# ['Hostel - 5.5km from city centre',
#  'Hostel - 1.8km from city centre',
#  'Hostel - 3km from city centre',
#  'Hostel - 5.4km from city centre',
#  'Hostel - 5km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hostel - 5.7km from city centre',
#  'Hostel - 7.6km from city centre',
#  'Hostel - 7km from city centre',
#  'Hostel - 4.2km from city centre',
#  'Hostel - 2.4km from city centre',
#  'Hostel - 5.1km from city centre',
#  'Hostel - 8.2km from city centre',
#  'Hostel - 4.7km from city centre',
#  'Hostel - 0.7km from city centre',
#  'Hotel - 3.2km from city centre',
#  'Hostel - 3.4km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hotel - 2.1km from city centre',
#  'Apartment - 8.2km from city centre',
#  'Hostel - 8.2km from city centre']

# %%
rating=[]

ratings=driver.find_elements(By.XPATH,'//div[@class="rating rating-summary-container big"]')

for i in ratings:
    rating.append(i.text)
rating
# Out:
# ['9.5\nSuperb\n1952 Total Reviews',
#  '7.7\nVery Good\n12048 Total Reviews',
#  '7.5\nVery Good\n7429 Total Reviews',
#  '9.2\nSuperb\n724 Total Reviews',
#  '7.4\nVery Good\n6562 Total Reviews',
#  '7.8\nVery Good\n4013 Total Reviews',
#  '6.9\nGood\n3445 Total Reviews',
#  '7.3\nVery Good\n3329 Total Reviews',
#  '6.5\nGood\n764 Total Reviews',
#  '7.3\nVery Good\n50 Total Reviews',
#  '7.4\nVery Good\n324 Total Reviews',
#  '8.6\nFabulous\n7 Total Reviews',
#  '5.1\nRating\n3706 Total Reviews',
#  '7.5\nVery Good\n298 Total Reviews',
#  '5.4\nRating\n2528 Total Reviews',
#  '8.0\nFabulous\n126 Total Reviews',
#  '6.6\nGood\n1072 Total Reviews',
#  '6.3\nGood\n443 Total Reviews',
#  'No Rating\n46 Total Reviews',
#  '2.6\nRating\n357 Total Reviews',
#  '5.7\nRating\n262 Total Reviews']

# %%
review=[]

reviews=driver.find_elements(By.XPATH,'//div[@class="reviews"]')

for i in reviews:
    review.append(i.text)
review
# Out:
# ['1952 Total Reviews',
#  '12048 Total Reviews',
#  '7429 Total Reviews',
#  '724 Total Reviews',
#  '6562 Total Reviews',
#  '4013 Total Reviews',
#  '3445 Total Reviews',
#  '3329 Total Reviews',
#  '764 Total Reviews',
#  '50 Total Reviews',
#  '324 Total Reviews',
#  '7 Total Reviews',
#  '3706 Total Reviews',
#  '298 Total Reviews',
#  '2528 Total Reviews',
#  '126 Total Reviews',
#  '1072 Total Reviews',
#  '443 Total Reviews',
#  '46 Total Reviews',
#  '357 Total Reviews',
#  '262 Total Reviews']

# %%
price=[]

prices=driver.find_elements(By.XPATH,'//div[@class="price title-5"]')[:21]

for i in prices:
    price.append(i.text)
price
# Out:
# ['Rs20898',
#  'Rs6658',
#  'Rs4110.84 Rs3700',
#  'Rs21345',
#  'Rs4290',
#  'Rs5478',
#  'Rs3805.72 Rs3425',
#  'Rs4375.84 Rs3938',
#  'Rs3388',
#  'Rs3083.04 Rs2775',
#  'Rs3959.8 Rs3564',
#  'Rs3741',
#  'Rs7121',
#  'Rs6712',
#  'Rs3066',
#  'Rs4940',
#  'Rs4231',
#  'Rs21124',
#  'Rs7087',
#  'Rs5043',
#  'Rs55597']

# %%
facility=[]

facility0=driver.find_elements(By.XPATH,'//span[@class="label"]')[:21]

for i in facility0:
    facility.append(i.text)
facility
# Out:
# ['Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi']

# %%
df=pd.DataFrame({'hostel':hostel_name,'distances':distance,'ratings':rating,'reviews':review,'prices':price,'facilities':facility})
df
# Out:
#                                  hostel                           distances  \
# 0               Hostel One Notting Hill     Hostel - 5.5km from city centre
# 1              St Christopher's Village     Hostel - 1.8km from city centre
# 2                      Generator London       Hostel - 3km from city centre
# 3                  Urbany Hostel London     Hostel - 5.4km from city centre
# 4            Smart Hyde Park Inn Hostel       Hostel - 5km from city centre
# 5               St Christopher's Camden     Hostel - 4.3km from city centre
# 6               Queen Elizabeth Chelsea     Hostel - 5.7km from city centre
# 7            St Christopher's Greenwich     Hostel - 7.6km from city centre
# 8       St Christopher's Shepherds Bush       Hostel - 7km from city centre
# 9                     Bell House Hostel     Hostel - 4.2km from city centre
# 10  PubLove @ The White Ferry, Victoria     Hostel - 2.4km from city centre
# ...
