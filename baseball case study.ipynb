# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.sum()
# Out:
# W        2429.00
# R       20647.00
# AB     165488.00
# H       42106.00
# 2B       8242.00
# 3B        939.00
# HR       4909.00
# BB      14073.00
# SO      37446.00
# SB       2505.00
# RA      20647.00
# ER      19075.00
# ERA       118.69
# CG        104.00
# SHO       339.00
# SV       1292.00
# E        2830.00
# dtype: float64

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.isnull())
plt.title('null values')
plt.show()

# %%
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.distplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.histplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber += 1
plt.show()

# %%
plt.figure(figsize=(25,50),facecolor='white')
plotnumber=1

for column in df:
    if plotnumber <=17:
        ax= plt.subplot(10,2,plotnumber)
        sns.boxplot(df[column],color='skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        ax = plt.subplot(7,4,plotnumber)
        plt.scatter(df[column],df['W'], color='b')
        plt.xlabel(column,fontsize=26)
        plt.ylabel('W', fontsize=26)
    plotnumber += 1
plt.tight_layout()

# %%
plt.figure(figsize = (25,20), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        plt.figure(figsize = (10,6))
        sns.regplot(df[column], df['W'])
        plt.xlabel(column)
        plt.ylabel('W')
        
plt.tight_layout()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize = [20, 15])
sns.heatmap(df.corr(), annot = True)
plt.title('Correlation Matrix')
plt.show()

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.plot(kind='box',fontsize=15,figsize=(25,25),color='b')
# Out:
# <AxesSubplot:>

# %%
#Features having outliers
features=df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df_new.shape
# Out:
# (29, 17)

# %%
df.shape
# Out:
# (30, 17)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
x = df_new.drop("W",axis=1)
y = df_new["W"]

# %%
ssc=StandardScaler()
X = pd.DataFrame(ssc.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.501486 -0.813262
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.501486  0.159299
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  2.854612 -0.326982
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.363013 -0.570122
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  1.363013  0.159299
#
#          SV         E
# 0  1.643157 -0.471091
# 1  0.211006 -0.614898
# 2 -0.700362 -1.118222
# 3 -0.830557  0.463653
# 4 -1.090948 -0.614898

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import  LinearRegression

LR=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state{i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
    print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is :-0.9813110675354016
# At random state0, The test accuracy is :-0.3212676880537526
#
#
# At random state1, The training accuracy is :-0.9726903849968482
# At random state1, The test accuracy is :-0.5526200953434566
#
#
# At random state2, The training accuracy is :-0.965473962017367
# At random state2, The test accuracy is :--0.18334787600549718
#
#
# At random state3, The training accuracy is :-0.9707815498962509
# At random state3, The test accuracy is :-0.5905937686680133
#
#
# At random state4, The training accuracy is :-0.9638069051194141
# At random state4, The test accuracy is :-0.7760427205275752
#
#
# At random state5, The training accuracy is :-0.9617987069171364
# At random state5, The test accuracy is :-0.5561762468530986
#
#
# At random state6, The training accuracy is :-0.9759979960717317
# At random state6, The test accuracy is :-0.7546871785943289
#
#
# At random state7, The training accuracy is :-0.9603166700336759
# At random state7, The test accuracy is :-0.4109578751199219
#
#
# At random state8, The training accuracy is :-0.9830143275152232
# At random state8, The test accuracy is :-0.6952311013865031
#
#
# At random state9, The training accuracy is :-0.9841945860552266
# At random state9, The test accuracy is :-0.6209725708235854
#
#
# At random state10, The training accuracy is :-0.9932817250357991
# At random state10, The test accuracy is :--0.2740042800480902
#
#
# At random state11, The training accuracy is :-0.9654463418089875
# At random state11, The test accuracy is :-0.5711590519883183
#
#
# At random state12, The training accuracy is :-0.9851573721962742
# At random state12, The test accuracy is :-0.5144819360627118
#
#
# At random state13, The training accuracy is :-0.9784747313695943
# At random state13, The test accuracy is :-0.31662740110819076
#
#
# At random state14, The training accuracy is :-0.9532498336443552
# At random state14, The test accuracy is :-0.8541750146005123
#
#
# At random state15, The training accuracy is :-0.9816117205088719
# At random state15, The test accuracy is :--0.1288258265622837
#
#
# At random state16, The training accuracy is :-0.9960611516687904
# At random state16, The test accuracy is :--0.5480651939179393
#
#
# At random state17, The training accuracy is :-0.9549578813070196
# At random state17, The test accuracy is :-0.8000874039958896
#
#
# At random state18, The training accuracy is :-0.9790645572027312
# At random state18, The test accuracy is :-0.19859455108161495
#
#
# At random state19, The training accuracy is :-0.9707755317438324
# At random state19, The test accuracy is :-0.1261605410587079
#
#
# At random state20, The training accuracy is :-0.9875899649915145
# At random state20, The test accuracy is :--1.5778750655173437
#
#
# At random state21, The training accuracy is :-0.9846090750874711
# At random state21, The test accuracy is :-0.0569130568145928
#
#
# At random state22, The training accuracy is :-0.9588998723940726
# At random state22, The test accuracy is :-0.6898176524964978
#
#
# At random state23, The training accuracy is :-0.97951513432623
# At random state23, The test accuracy is :-0.7348780512412652
#
#
# At random state24, The training accuracy is :-0.9944952617509831
# At random state24, The test accuracy is :--1.8516247030588553
#
#
# At random state25, The training accuracy is :-0.9681274904145779
# At random state25, The test accuracy is :--0.054961428587605
#
#
# At random state26, The training accuracy is :-0.9567882207674373
# At random state26, The test accuracy is :-0.5942047020716135
#
#
# At random state27, The training accuracy is :-0.9779262996302998
# At random state27, The test accuracy is :-0.7606318560738514
#
#
# At random state28, The training accuracy is :-0.9836421314864525
# At random state28, The test accuracy is :-0.1256329591141272
#
#
# At random state29, The training accuracy is :-0.9606198368888889
# At random state29, The test accuracy is :-0.7915879199947776
#
#
# At random state30, The training accuracy is :-0.9514477716425856
# At random state30, The test accuracy is :-0.8928273815873446
#
#
# At random state31, The training accuracy is :-0.9845605265109332
# At random state31, The test accuracy is :-0.03469299385534741
#
#
# At random state32, The training accuracy is :-0.9748993604446705
# At random state32, The test accuracy is :-0.34674319241057405
#
#
# At random state33, The training accuracy is :-0.9612293043871818
# At random state33, The test accuracy is :-0.6964849190711193
#
#
# At random state34, The training accuracy is :-0.983901335177355
# At random state34, The test accuracy is :-0.5466529540183511
#
#
# At random state35, The training accuracy is :-0.9798538602233575
# At random state35, The test accuracy is :-0.8316683004720077
#
#
# At random state36, The training accuracy is :-0.9832847024385386
# At random state36, The test accuracy is :-0.09494640146649846
#
#
# At random state37, The training accuracy is :-0.9833841570510443
# At random state37, The test accuracy is :--0.13748011025152285
#
#
# At random state38, The training accuracy is :-0.9606886644333074
# At random state38, The test accuracy is :-0.5220477956747018
#
#
# At random state39, The training accuracy is :-0.9854335401196853
# At random state39, The test accuracy is :--0.09499060603878018
#
#
# At random state40, The training accuracy is :-0.9858941352019682
# At random state40, The test accuracy is :-0.24982463821731293
#
#
# At random state41, The training accuracy is :-0.9513238487503941
# At random state41, The test accuracy is :-0.898493503376953
#
#
# At random state42, The training accuracy is :-0.9658874959407933
# At random state42, The test accuracy is :-0.23042744779257396
#
#
# At random state43, The training accuracy is :-0.9915085623741517
# At random state43, The test accuracy is :--2.5558836850181725
#
#
# At random state44, The training accuracy is :-0.9833018199194213
# At random state44, The test accuracy is :-0.06785833819979392
#
#
# At random state45, The training accuracy is :-0.9836068454142821
# At random state45, The test accuracy is :-0.36479621517095084
#
#
# At random state46, The training accuracy is :-0.9677294014163051
# At random state46, The test accuracy is :-0.12287990011567584
#
#
# At random state47, The training accuracy is :-0.972739686379078
# At random state47, The test accuracy is :-0.008037010014340984
#
#
# At random state48, The training accuracy is :-0.9889116414664795
# At random state48, The test accuracy is :--1.3864169883672446
#
#
# At random state49, The training accuracy is :-0.9819389298050236
# At random state49, The test accuracy is :--0.14467619847456548
#
#
# At random state50, The training accuracy is :-0.9487278084437882
# At random state50, The test accuracy is :-0.89019415196117
#
#
# At random state51, The training accuracy is :-0.9735988628491407
# At random state51, The test accuracy is :-0.7435191904140823
#
#
# At random state52, The training accuracy is :-0.9905719888954739
# At random state52, The test accuracy is :--0.0565902246545269
#
#
# At random state53, The training accuracy is :-0.9705653785313263
# At random state53, The test accuracy is :-0.6087646977546431
#
#
# At random state54, The training accuracy is :-0.9731101336740637
# At random state54, The test accuracy is :-0.1185504208186412
#
#
# At random state55, The training accuracy is :-0.9587801718736023
# At random state55, The test accuracy is :-0.39096112114674
#
#
# At random state56, The training accuracy is :-0.9783946827625096
# At random state56, The test accuracy is :-0.7567895815889738
#
#
# At random state57, The training accuracy is :-0.9821260701728386
# At random state57, The test accuracy is :-0.571255931777389
#
#
# At random state58, The training accuracy is :-0.9899712871878722
# At random state58, The test accuracy is :-0.6885437465105608
#
#
# At random state59, The training accuracy is :-0.9759811156408797
# At random state59, The test accuracy is :-0.8233675044298175
#
#
# At random state60, The training accuracy is :-0.989463202836234
# At random state60, The test accuracy is :-0.09173065339239506
#
#
# At random state61, The training accuracy is :-0.9769894536417487
# At random state61, The test accuracy is :-0.7349302844211365
#
#
# At random state62, The training accuracy is :-0.9868592792588545
# At random state62, The test accuracy is :-0.7609541325908962
#
#
# At random state63, The training accuracy is :-0.9859468516070271
# At random state63, The test accuracy is :-0.41575756517553486
#
#
# At random state64, The training accuracy is :-0.9499944930409623
# At random state64, The test accuracy is :-0.8682565059040566
#
#
# At random state65, The training accuracy is :-0.9849051178599652
# At random state65, The test accuracy is :-0.1912423241937652
#
#
# At random state66, The training accuracy is :-0.9558546162599453
# At random state66, The test accuracy is :-0.6508254740647409
#
#
# At random state67, The training accuracy is :-0.9589847402802445
# At random state67, The test accuracy is :-0.6255621015699759
#
#
# At random state68, The training accuracy is :-0.9630697104515189
# At random state68, The test accuracy is :-0.5752051351378131
#
#
# At random state69, The training accuracy is :-0.9803056977600552
# At random state69, The test accuracy is :-0.38045607954522676
#
#
# At random state70, The training accuracy is :-0.972644888462845
# At random state70, The test accuracy is :-0.4156032218813852
#
#
# At random state71, The training accuracy is :-0.9941247349548592
# At random state71, The test accuracy is :--2.459346167003882
#
#
# At random state72, The training accuracy is :-0.9659789587859356
# At random state72, The test accuracy is :--0.369958085012317
#
#
# At random state73, The training accuracy is :-0.9865366041232835
# At random state73, The test accuracy is :--0.46166117070586576
#
#
# At random state74, The training accuracy is :-0.9672891768264092
# At random state74, The test accuracy is :-0.3229674109360756
#
#
# At random state75, The training accuracy is :-0.9770883771688554
# At random state75, The test accuracy is :-0.24420555724578308
#
#
# At random state76, The training accuracy is :-0.9725876685124402
# At random state76, The test accuracy is :-0.5549407859619588
#
#
# At random state77, The training accuracy is :-0.954466158041274
# At random state77, The test accuracy is :-0.8385043744963245
#
#
# At random state78, The training accuracy is :-0.9606960816784081
# At random state78, The test accuracy is :-0.4574515864178027
#
#
# At random state79, The training accuracy is :-0.9804984439082762
# At random state79, The test accuracy is :-0.6089674924431286
#
#
# At random state80, The training accuracy is :-0.9748448524933726
# At random state80, The test accuracy is :-0.620382285009529
#
#
# At random state81, The training accuracy is :-0.9802224364245309
# At random state81, The test accuracy is :-0.7107178772520214
#
#
# At random state82, The training accuracy is :-0.9775385186035621
# At random state82, The test accuracy is :-0.2722298008243733
#
#
# At random state83, The training accuracy is :-0.9807554264884887
# At random state83, The test accuracy is :-0.15443296566978326
#
#
# At random state84, The training accuracy is :-0.9880626398054722
# At random state84, The test accuracy is :-0.06304045048812446
#
#
# At random state85, The training accuracy is :-0.9662151409022728
# At random state85, The test accuracy is :-0.2128842976239238
#
#
# At random state86, The training accuracy is :-0.9681554063766478
# At random state86, The test accuracy is :--1.4352579822426947
#
#
# At random state87, The training accuracy is :-0.9619509119355044
# At random state87, The test accuracy is :-0.4024045289057223
#
#
# At random state88, The training accuracy is :-0.9960704524134653
# At random state88, The test accuracy is :--2.0630417203262343
#
#
# At random state89, The training accuracy is :-0.964774490460573
# At random state89, The test accuracy is :-0.5866902507022822
#
#
# At random state90, The training accuracy is :-0.9636779695959765
# At random state90, The test accuracy is :-0.6236008669700273
#
#
# At random state91, The training accuracy is :-0.9881882700317499
# At random state91, The test accuracy is :-0.5656008335270087
#
#
# At random state92, The training accuracy is :-0.9923470992004296
# At random state92, The test accuracy is :-0.45391489842769406
#
#
# At random state93, The training accuracy is :-0.9738328795605429
# At random state93, The test accuracy is :--1.499982751097757
#
#
# At random state94, The training accuracy is :-0.9799329648923685
# At random state94, The test accuracy is :--1.3219959689110774
#
#
# At random state95, The training accuracy is :-0.972495491378054
# At random state95, The test accuracy is :-0.40418727712607894
#
#
# At random state96, The training accuracy is :-0.9937232870466386
# At random state96, The test accuracy is :--1.0536160159917438
#
#
# At random state97, The training accuracy is :-0.9616382908908928
# At random state97, The test accuracy is :-0.6085868473091145
#
#
# At random state98, The training accuracy is :-0.9927291256957081
# At random state98, The test accuracy is :--1.502126862654047
# At random state99, The training accuracy is :-0.9606451190270185
# At random state99, The test accuracy is :-0.8473754088703267

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=99)

# %%
x_train.shape
# Out:
# (22, 16)

# %%
y_train.shape
# Out:
# (22,)

# %%
x_test.shape
# Out:
# (7, 16)

# %%
y_test.shape
# Out:
# (7,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
Linear=LinearRegression()
Linear.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.9606451190270185
